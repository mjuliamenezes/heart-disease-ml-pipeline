# %% [markdown]
# ### 02 - Pré-processamento dos Dados
#
# Neste notebook aplicou-se o pré-processamento customizado baseado na análise exploratória

# %% [markdown]
# # Imports

# %%
import sys
sys.path.append('/home/jovyan/work')

import pandas as pd
import numpy as np
from src import S3Client, DataPreprocessor

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Carregar Dados do MinIO

# %%
s3 = S3Client()

# Carregar train, test e validation
train_df = s3.read_csv('processed/train.csv')
test_df = s3.read_csv('processed/test.csv')
validation_df = s3.read_csv('processed/validation.csv')

print(f"📊 Train: {train_df.shape}")
print(f"📊 Test: {test_df.shape}")
print(f"📊 Validation: {validation_df.shape}")
# Out:
# INFO:src.s3_utils:S3 Client inicializado: http://minio:9000/ml-bucket-heart
# INFO:src.s3_utils:✅ CSV lido: s3://ml-bucket-heart/processed/train.csv (714 linhas)
# INFO:src.s3_utils:✅ CSV lido: s3://ml-bucket-heart/processed/test.csv (238 linhas)
# INFO:src.s3_utils:✅ CSV lido: s3://ml-bucket-heart/processed/validation.csv (238 linhas)
# 📊 Train: (714, 12)
# 📊 Test: (238, 12)
# 📊 Validation: (238, 12)

# %% [markdown]
# # Verificar Dados Brutos

# %%
print("\n--- Primeiras linhas (Train) ---")
display(train_df.head())

print("\n--- Info ---")
train_df.info()

print("\n--- Estatísticas ---")
display(train_df.describe())
# Out:
# --- Primeiras linhas (Train) ---
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   63    0                4           150          407                    0
# 1   63    1                4           130          254                    0
# 2   61    0                4           145          307                    0
# 3   48    1                2           110          229                    0
# 4   64    1                4           145          212                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            2             154                0      4.0         2       1
# 1            2             147                0      1.4         2       1
# 2            2             146                1      1.0         2       1
# 3            0             168                0      1.0         3       1
# 4            2             132                0      2.0         2       1
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  714 non-null    int64
#  1   sex                  714 non-null    int64
#  2   chest pain type      714 non-null    int64
#  3   resting bp s         714 non-null    int64
#  4   cholesterol          714 non-null    int64
#  5   fasting blood sugar  714 non-null    int64
#  6   resting ecg          714 non-null    int64
#  7   max heart rate       714 non-null    int64
#  8   exercise angina      714 non-null    int64
#  9   oldpeak              714 non-null    float64
#  10  ST slope             714 non-null    int64
#  11  target               714 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 67.1 KB
#
# --- Estatísticas ---
#               age         sex  chest pain type  resting bp s  cholesterol  \
# count  714.000000  714.000000       714.000000    714.000000   714.000000
# mean    53.754902    0.760504         3.219888    132.016807   214.413165
# std      9.386370    0.427075         0.952208     18.525438    96.340510
# min     29.000000    0.000000         1.000000      0.000000     0.000000
# 25%     47.000000    1.000000         3.000000    120.000000   197.000000
# 50%     54.000000    1.000000         4.000000    130.000000   230.000000
# 75%     60.000000    1.000000         4.000000    140.000000   269.750000
# max     77.000000    1.000000         4.000000    200.000000   564.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count           714.000000   714.000000      714.000000       714.000000
# mean              0.212885     0.747899      140.243697         0.376751
# std               0.409634     0.886728       25.287952         0.484911
# min               0.000000     0.000000       60.000000         0.000000
# 25%               0.000000     0.000000      122.000000         0.000000
# 50%               0.000000     0.000000      142.000000         0.000000
# 75%               0.000000     2.000000      160.000000         1.000000
# max               1.000000     2.000000      202.000000         1.000000
#
#           oldpeak    ST slope      target
# count  714.000000  714.000000  714.000000
# mean     0.945378    1.637255    0.528011
# std      1.080744    0.611999    0.499565
# min     -2.000000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000
# 50%      0.800000    2.000000    1.000000
# 75%      1.600000    2.000000    1.000000
# max      6.200000    3.000000    1.000000

# %% [markdown]
# # Inicializar Preprocessador

# %%
preprocessor = DataPreprocessor()
# Out:
# INFO:src.data_preprocessing:DataPreprocessor inicializado

# %% [markdown]
# # Limpeza

# %%
train_clean = preprocessor.clean_heart_disease_data(train_df)
test_clean = preprocessor.clean_heart_disease_data(test_df)
validation_clean = preprocessor.clean_heart_disease_data(validation_df)
# Out:
# INFO:src.data_preprocessing:🔄 Iniciando limpeza customizada do Heart Disease dataset...
# INFO:src.data_preprocessing:✅ Duplicatas removidas: 714 -> 602 linhas
# INFO:src.data_preprocessing:✅ resting bp s: 1 valores 0 substituídos por mediana (130.0)
# INFO:src.data_preprocessing:✅ cholesterol: 91 valores 0 substituídos por mediana (239.0)
# INFO:src.data_preprocessing:📊 Distribuição do target: {1: 325, 0: 277}
# INFO:src.data_preprocessing:✅ Dataset limpo: (602, 12)
# INFO:src.data_preprocessing:🔄 Iniciando limpeza customizada do Heart Disease dataset...
# INFO:src.data_preprocessing:✅ Duplicatas removidas: 238 -> 232 linhas
# INFO:src.data_preprocessing:✅ cholesterol: 38 valores 0 substituídos por mediana (239.5)
# INFO:src.data_preprocessing:📊 Distribuição do target: {1: 124, 0: 108}
# INFO:src.data_preprocessing:✅ Dataset limpo: (232, 12)
# INFO:src.data_preprocessing:🔄 Iniciando limpeza customizada do Heart Disease dataset...
# INFO:src.data_preprocessing:✅ Duplicatas removidas: 238 -> 227 linhas
# INFO:src.data_preprocessing:✅ cholesterol: 43 valores 0 substituídos por mediana (236.0)
# INFO:src.data_preprocessing:📊 Distribuição do target: {1: 120, 0: 107}
# INFO:src.data_preprocessing:✅ Dataset limpo: (227, 12)

# %% [markdown]
# # Encoding

# %%
# Aplicar One-Hot Encoding
categorical_cols = ["chest pain type", "resting ecg", "ST slope"]

# FIT no treino (cria o encoder)
train_encoded = preprocessor.apply_onehot_encoding(train_clean, categorical_cols, fit=True)

# TRANSFORM no teste e validação (usa o mesmo encoder)
test_encoded = preprocessor.apply_onehot_encoding(test_clean, categorical_cols, fit=False)
validation_encoded = preprocessor.apply_onehot_encoding(validation_clean, categorical_cols, fit=False)

print(f"\n✅ Train encoded: {train_encoded.shape}")
print(f"✅ Test encoded: {test_encoded.shape}")
print(f"✅ Validation encoded: {validation_encoded.shape}")
# Out:
# INFO:src.data_preprocessing:🔄 Criando OneHotEncoder e fazendo fit em: ['chest pain type', 'resting ecg', 'ST slope']
# INFO:src.data_preprocessing:✅ One-Hot Encoding: 12 -> 20 colunas
# INFO:src.data_preprocessing:🔄 Aplicando OneHotEncoder já ajustado em: ['chest pain type', 'resting ecg', 'ST slope']
# INFO:src.data_preprocessing:✅ One-Hot Encoding: 12 -> 20 colunas
# INFO:src.data_preprocessing:🔄 Aplicando OneHotEncoder já ajustado em: ['chest pain type', 'resting ecg', 'ST slope']
# INFO:src.data_preprocessing:✅ One-Hot Encoding: 12 -> 20 colunas
# ✅ Train encoded: (602, 20)
# ✅ Test encoded: (232, 20)
# ✅ Validation encoded: (227, 20)

# %% [markdown]
# # Spliting

# %%
X_train, y_train = preprocessor.load_data(train_encoded, target_col='target')
X_test, y_test = preprocessor.load_data(test_encoded, target_col='target')
X_val, y_val = preprocessor.load_data(validation_encoded, target_col='target')
# Out:
# INFO:src.data_preprocessing:✅ Dados carregados: 602 amostras, 19 features
# INFO:src.data_preprocessing:📊 Distribuição do target: {1: 325, 0: 277}
# INFO:src.data_preprocessing:✅ Dados carregados: 232 amostras, 19 features
# INFO:src.data_preprocessing:📊 Distribuição do target: {1: 124, 0: 108}
# INFO:src.data_preprocessing:✅ Dados carregados: 227 amostras, 19 features
# INFO:src.data_preprocessing:📊 Distribuição do target: {1: 120, 0: 107}

# %% [markdown]
# # Scaling

# %%
numeric_cols = ["age", "resting bp s", "cholesterol", 
                "fasting blood sugar", "max heart rate", "oldpeak"]

# Fit no treino, transform em todos
X_train_scaled, _ = preprocessor.normalize_features(X_train, method='standard')
X_test_scaled = pd.DataFrame(
    preprocessor.scaler.transform(X_test),
    columns=X_test.columns,
    index=X_test.index
)
X_val_scaled = pd.DataFrame(
    preprocessor.scaler.transform(X_val),
    columns=X_val.columns,
    index=X_val.index
)

print("\n✅ Normalização concluída!")
print(f"Train: {X_train_scaled.shape}")
print(f"Test: {X_test_scaled.shape}")
print(f"Validation: {X_val_scaled.shape}")
# Out:
# INFO:src.data_preprocessing:✅ Features normalizadas (standard): (602, 19)
# ✅ Normalização concluída!
# Train: (602, 19)
# Test: (232, 19)
# Validation: (227, 19)

# %% [markdown]
# # Salvar os dados processados no MinIO

# %%
# Salvar dados processados de volta no MinIO
s3.write_csv(X_train_scaled, 'processed/X_train_scaled.csv')
s3.write_csv(X_test_scaled, 'processed/X_test_scaled.csv')
s3.write_csv(X_val_scaled, 'processed/X_val_scaled.csv')

# Salvar targets direto no MinIO (convertendo Series para DataFrame)
s3.write_csv(pd.DataFrame(y_train), 'processed/y_train.csv')
s3.write_csv(pd.DataFrame(y_test), 'processed/y_test.csv')
s3.write_csv(pd.DataFrame(y_val), 'processed/y_val.csv')

print("\n✅ Dados salvos no MinIO!")
# Out:
# INFO:src.s3_utils:✅ CSV salvo: s3://ml-bucket-heart/processed/X_train_scaled.csv
# INFO:src.s3_utils:✅ CSV salvo: s3://ml-bucket-heart/processed/X_test_scaled.csv
# INFO:src.s3_utils:✅ CSV salvo: s3://ml-bucket-heart/processed/X_val_scaled.csv
# INFO:src.s3_utils:✅ CSV salvo: s3://ml-bucket-heart/processed/y_train.csv
# INFO:src.s3_utils:✅ CSV salvo: s3://ml-bucket-heart/processed/y_test.csv
# INFO:src.s3_utils:✅ CSV salvo: s3://ml-bucket-heart/processed/y_val.csv
# ✅ Dados salvos no MinIO!
